# %%
from model import *
from reader import *

# %%
opts = Options()
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

sess = tf.InteractiveSession(config=config)
use_jeval = True

# %% [markdown]
# ## readme
# #### 1. unpack data.tar.gz
# #### 2. select a model of followings to build (FB15K-237, FB15K, and WN18)
# #### 3. run codes

# %%
file_name = '237-dskg-hs512'

opts.data_path = 'data/FB15k-237/'

opts.hidden_size = 512
opts.num_samples = 2048*3
opts.keep_prob = 0.5
opts.num_layers = 2
opts.learning_rate=0.001

model = FBRespective(opts, sess)
# model.saver.restore(save_path='ckpt/237-dskg-hs512_4', sess= sess)
# Out:
# load file from local
# start gen filter mat
# WARNING:tensorflow:From /home/lingbing/Projects/kgcompletion/implementations/DSKG/model.py:379: get_or_create_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_or_create_global_step

# %%
file_name = 'fb-dskg-hs512'

opts.hidden_size = 512
opts.num_samples = 2048*3
opts.keep_prob = 0.5
opts.num_layers = 2
opts.learning_rate=0.001

model = FBRespective(opts, sess)
# model.saver.restore(save_path='ckpt/fb-dskg-hs512_4', sess= sess)

# %%
file_name = 'wn-dskg-hs512'

opts.hidden_size = 512
opts.num_samples = 2048*3
opts.keep_prob = 0.5
opts.num_layers = 2
opts.learning_rate=0.001

opts.data_path = 'data/wordnet-mlj12/'

model = WNRespective(opts, sess)

# %%
def cal_ranks(probs, method, label):
    if method == 'min':
        probs = probs - probs[range(len(label)), label].reshape(len(probs), 1)
        ranks = (probs > 0).sum(axis=1) + 1
    else:
        ranks = pd.DataFrame(probs).rank(axis=1, ascending=False, method=method)
        ranks = ranks.values[range(len(label)), label]
    return ranks

def cal_performance(ranks, top=10):
    m_r = sum(ranks) * 1.0 / len(ranks)
    h_10 = sum(ranks <= top) * 1.0 / len(ranks)
    mrr = (1. / ranks).sum() / len(ranks)
    return m_r, h_10, mrr

def eval_entity_prediction(model, data, filter_mat, method='min', return_ranks=False, return_probs=False, return_label_probs=False):
    options = model._options
    batch_size = options.batch_size
    
    label = data[:, 2]
    
    data, padding_num = model.padding_data(data)

    num_batch = len(data) // batch_size 
    
    e_placeholder, r_placeholder, fectch_entity_probs = model._eval_e, model._eval_r, model._entity_probs
    
    probs = []
    for i in range(num_batch):
        e = data[:, 0][i * batch_size:(i + 1) * batch_size]
        r = data[:, 1][i * batch_size:(i + 1) * batch_size]
        
        feed_dict = {}
        feed_dict[e_placeholder] = e
        feed_dict[r_placeholder] = r
        
        probs.append(sess.run(fectch_entity_probs, feed_dict))
    probs = np.concatenate(probs)[:len(data) - padding_num]

    if return_label_probs:
        return probs[range(len(label)), label]
    
    if return_probs:
        return probs

    filter_probs = probs * filter_mat
    filter_probs[range(len(label)), label] = probs[range(len(label)), label]

    filter_ranks = cal_ranks(filter_probs, method=method, label=label)
    if return_ranks:
        return filter_ranks
    ranks = cal_ranks(probs, method=method, label=label)
    m_r, h_10, mrr = cal_performance(ranks)
    f_m_r, f_h_10, f_mrr = cal_performance(filter_ranks)
    
    return (m_r, h_10, mrr, f_m_r, f_h_10, f_mrr)

def eval_relation_prediction(model, data, filter_mat, method='min', return_ranks=False, return_probs=False):
    options = model._options
    batch_size = options.batch_size
    
    #data[:, 0]-->e, data[:, 1]-->r, data[:, 2]-->e2
    label = data[:, 1]
    
    data, padding_num = model.padding_data(data)

    num_batch = len(data) // batch_size
    
    e_placeholder, fectch_relation_probs = model._eval_e, model._relation_probs
    
    probs = []
    
    for i in range(num_batch):
        e = data[:, 0][i * batch_size:(i + 1) * batch_size]
        
        feed_dict = {}
        feed_dict[e_placeholder] = e
        
        probs.append(sess.run(fectch_relation_probs, feed_dict))
        
    probs = np.concatenate(probs)[:len(data) - padding_num]
    return probs

# %%
test_data = np.array(model._test_data[['h_id', 'r_id', 't_id']].values)
train_data = model._train_data[['h_id', 'r_id', 't_id']].values
valid_data = model._valid_data[['h_id', 'r_id', 't_id']].values
filter_mat = model._tail_test_filter_mat
vfilter_mat = model._tail_valid_filter_mat

all_data = np.concatenate([train_data, test_data,valid_data])
p_data = np.concatenate([test_data,valid_data])

def gen_rev_rel(test_data):
    half = len(test_data)//2
    forward = test_data[:half]
    back = test_data[half:]
    rev_rel_test_data = test_data[:]
    rev_rel = np.concatenate([back[:,1], forward[:,1]])
    return rev_rel

rev_rel = gen_rev_rel(test_data)
vrev_rel=  gen_rev_rel(valid_data)

rev_rel_test_data = np.stack([np.arange(model._entity_num),np.arange(model._entity_num)], axis=1)

# %%
def cal_r(probs, label, filter_mat):
    filter_probs = probs * filter_mat
    
    filter_probs[range(len(label)), label] = probs[range(len(label)), label]
    filter_ranks = cal_ranks(filter_probs, method='min', label=label)
    
    return filter_ranks




def joint_eval(test_data, filter_mat, rev_rel):
    label=test_data[:, 2]

    ep =  eval_entity_prediction(model, data=test_data, filter_mat=filter_mat, return_probs=True)
    efr = cal_r(ep, label, filter_mat)
    if use_jeval:
        rp = eval_relation_prediction(model, rev_rel_test_data, filter_mat=None, return_probs=True).T
        rp = rp**0.33
        rp = rp[rev_rel]
        joint_probs = ep * rp
        joint_fr = cal_r(joint_probs, label, filter_mat)
    else:
        joint_fr = efr
    return joint_fr, efr

def joint_eval_raw(test_data, filter_mat, rev_rel):
    label=test_data[:, 2]
    
    
    ep =  eval_entity_prediction(model, data=test_data, filter_mat=filter_mat, return_probs=True)
    efr = cal_ranks(ep, method='min', label=label)
    if use_jeval:
        rp = eval_relation_prediction(model, rev_rel_test_data, filter_mat=None, return_probs=True).T
        rp = rp**0.33
        rp = rp[rev_rel]
        joint_probs = ep * rp
        joint_fr = cal_ranks(joint_probs, method='min', label=label)
    else:
        joint_fr = efr
    return joint_fr, efr

def process_ranks(efr, i=0, last_mean_loss=1000, title=''):

    MR, H1, MRR = cal_performance(efr[:len(efr)], top=1)
    _, H10, _ = cal_performance(efr[:len(efr)], top=10)
    msg = '%s epoch:%i, Hits@1:%.3f, Hits@10:%.3f, MR:%.3f, MRR:%.3f, mean_loss:%.3f' % (format(title,'<15'), i, H1, H10, MR, MRR, last_mean_loss)
    print(msg)
    return (i, H1, H10, MR, MRR, last_mean_loss)

def handle_eval(i=0, last_mean_loss=1000, valid=True, test=True):
    if valid:
        jfr, efr = joint_eval(test_data=valid_data, filter_mat=vfilter_mat, rev_rel=vrev_rel)
        jrr, rr = joint_eval_raw(test_data=valid_data, filter_mat=vfilter_mat, rev_rel=vrev_rel)
        
        process_ranks(rr, i, last_mean_loss, title='Valid-R')
        process_ranks(jrr, i, last_mean_loss, title='Valid-R-RH')
        
        msg = process_ranks(efr, i, last_mean_loss, title='Valid-F')
        jmsg = process_ranks(jfr, i, last_mean_loss, title='Valid-F-RH')
        
        
        
        
        
        valid_results.append(msg)
        valid_results.append(jmsg)
        if i % 50 == 0:
            pd.DataFrame(valid_results, columns=['epoch','Hits@1', 'Hits@10', 'MR', 'MRR', 'mean_loss']).to_csv('results/'+file_name+'valid')
        
    if test:
        jfr, efr = joint_eval(test_data=test_data, filter_mat=filter_mat, rev_rel=rev_rel)
        jrr, rr = joint_eval_raw(test_data=test_data, filter_mat=filter_mat, rev_rel=rev_rel)
        
        process_ranks(rr, i, last_mean_loss, title='Test-R')
        process_ranks(jrr, i, last_mean_loss, title='Test-R-RH')
        
        
        msg = process_ranks(efr, i, last_mean_loss, title='Test-F')
        jmsg = process_ranks(jfr, i, last_mean_loss, title='Test-F-RH')
        results.append(msg)
        results.append(jmsg)
        if i % 50 == 0:
            pd.DataFrame(results, columns=['epoch','Hits@1', 'Hits@10', 'MR', 'MRR', 'mean_loss']).to_csv('results/'+file_name+'test')
    return

# %%
epoch =0
results = []
valid_results = []
last_mean_loss=1000

# %% [markdown]
# ## the function handle_eval(i=i, last_mean_loss=last_mean_loss, valid=True, test=True) will return 8 results:
#
# **Valid** and **Test** denote the datasets
#
# **R** denotes Raw results
#
# **F** denotes Filtered results
#
# **RH** denotes using relation enhancement method

# %%
for i in range(epoch, 300):
    if i % 20 == 0:
        handle_eval(i=i, last_mean_loss=last_mean_loss, valid=True, test=True)
    last_mean_loss = model.train()
    epoch += 1
# Out:
# Valid-R        :epoch:0, Hits@1:0.000, Hits@10:0.001, MR:7261.435, MRR:0.001, mean_loss:1000.000
# Valid-R-RH     :epoch:0, Hits@1:0.000, Hits@10:0.001, MR:7264.467, MRR:0.001, mean_loss:1000.000
# Valid-F        :epoch:0, Hits@1:0.000, Hits@10:0.001, MR:7141.450, MRR:0.001, mean_loss:1000.000
# Valid-F-RH     :epoch:0, Hits@1:0.000, Hits@10:0.001, MR:7144.876, MRR:0.001, mean_loss:1000.000
# Test-R         :epoch:0, Hits@1:0.000, Hits@10:0.001, MR:7243.157, MRR:0.001, mean_loss:1000.000
# Test-R-RH      :epoch:0, Hits@1:0.000, Hits@10:0.001, MR:7263.758, MRR:0.001, mean_loss:1000.000
# Test-F         :epoch:0, Hits@1:0.000, Hits@10:0.001, MR:7124.263, MRR:0.001, mean_loss:1000.000
# Test-F-RH      :epoch:0, Hits@1:0.000, Hits@10:0.001, MR:7145.014, MRR:0.001, mean_loss:1000.000
# 2048 265 0.001 100000
# 2048 265 0.001 9.09612939763
# 2048 265 0.001 7.27755485211
# 2048 265 0.001 6.81524581729
# 2048 265 0.001 6.51858349746
# Valid-R        :epoch:5, Hits@1:0.121, Hits@10:0.323, MR:364.610, MRR:0.186, mean_loss:6.307
# Valid-R-RH     :epoch:5, Hits@1:0.120, Hits@10:0.323, MR:355.375, MRR:0.186, mean_loss:6.307
# Valid-F        :epoch:5, Hits@1:0.196, Hits@10:0.436, MR:222.618, MRR:0.277, mean_loss:6.307
# Valid-F-RH     :epoch:5, Hits@1:0.197, Hits@10:0.439, MR:211.917, MRR:0.278, mean_loss:6.307
# Test-R         :epoch:5, Hits@1:0.118, Hits@10:0.319, MR:369.460, MRR:0.184, mean_loss:6.307
# Test-R-RH      :epoch:5, Hits@1:0.118, Hits@10:0.320, MR:359.602, MRR:0.185, mean_loss:6.307
# Test-F         :epoch:5, Hits@1:0.194, Hits@10:0.433, MR:228.901, MRR:0.274, mean_loss:6.307
# Test-F-RH      :epoch:5, Hits@1:0.194, Hits@10:0.437, MR:217.507, MRR:0.276, mean_loss:6.307
# 2048 265 0.001 6.30726179627
# 2048 265 0.001 6.15262640287
# 2048 265 0.001 6.03128068492
# 2048 265 0.001 5.93346677096
# 2048 265 0.001 5.85475419962
# Valid-R        :epoch:10, Hits@1:0.121, Hits@10:0.334, MR:353.807, MRR:0.190, mean_loss:5.784
# Valid-R-RH     :epoch:10, Hits@1:0.121, Hits@10:0.335, MR:337.652, MRR:0.191, mean_loss:5.784
# Valid-F        :epoch:10, Hits@1:0.230, Hits@10:0.489, MR:179.759, MRR:0.316, mean_loss:5.784
# Valid-F-RH     :epoch:10, Hits@1:0.231, Hits@10:0.491, MR:162.526, MRR:0.317, mean_loss:5.784
# Test-R         :epoch:10, Hits@1:0.119, Hits@10:0.331, MR:356.945, MRR:0.188, mean_loss:5.784
# Test-R-RH      :epoch:10, Hits@1:0.119, Hits@10:0.332, MR:339.137, MRR:0.189, mean_loss:5.784
# Test-F         :epoch:10, Hits@1:0.227, Hits@10:0.487, MR:186.637, MRR:0.314, mean_loss:5.784
# Test-F-RH      :epoch:10, Hits@1:0.229, Hits@10:0.489, MR:167.949, MRR:0.315, mean_loss:5.784
# 2048 265 0.001 5.78417100906
# 2048 265 0.001 5.72612218317
# 2048 265 0.001 5.67679643991
# 2048 265 0.001 5.62935299424
# 2048 265 0.001 5.59314615142
# Valid-R        :epoch:15, Hits@1:0.117, Hits@10:0.328, MR:365.137, MRR:0.185, mean_loss:5.553
# Valid-R-RH     :epoch:15, Hits@1:0.118, Hits@10:0.329, MR:343.868, MRR:0.187, mean_loss:5.553
# Valid-F        :epoch:15, Hits@1:0.230, Hits@10:0.498, MR:179.227, MRR:0.319, mean_loss:5.553
# Valid-F-RH     :epoch:15, Hits@1:0.230, Hits@10:0.499, MR:157.648, MRR:0.320, mean_loss:5.553
# Test-R         :epoch:15, Hits@1:0.116, Hits@10:0.325, MR:367.993, MRR:0.184, mean_loss:5.553
# Test-R-RH      :epoch:15, Hits@1:0.116, Hits@10:0.327, MR:344.677, MRR:0.185, mean_loss:5.553
# Test-F         :epoch:15, Hits@1:0.227, Hits@10:0.496, MR:186.304, MRR:0.316, mean_loss:5.553
# Test-F-RH      :epoch:15, Hits@1:0.229, Hits@10:0.497, MR:162.640, MRR:0.318, mean_loss:5.553
# 2048 265 0.001 5.55292730691
# 2048 265 0.001 5.52430053747
# 2048 265 0.001 5.49210429102
# 2048 265 0.001 5.46702660075
# 2048 265 0.001 5.44125039263
# Valid-R        :epoch:20, Hits@1:0.112, Hits@10:0.328, MR:369.175, MRR:0.181, mean_loss:5.417
# Valid-R-RH     :epoch:20, Hits@1:0.113, Hits@10:0.329, MR:346.802, MRR:0.182, mean_loss:5.417
# Valid-F        :epoch:20, Hits@1:0.236, Hits@10:0.504, MR:178.179, MRR:0.325, mean_loss:5.417
# Valid-F-RH     :epoch:20, Hits@1:0.236, Hits@10:0.505, MR:155.895, MRR:0.325, mean_loss:5.417
# Test-R         :epoch:20, Hits@1:0.112, Hits@10:0.324, MR:375.069, MRR:0.180, mean_loss:5.417
# Test-R-RH      :epoch:20, Hits@1:0.112, Hits@10:0.325, MR:349.796, MRR:0.181, mean_loss:5.417
# Test-F         :epoch:20, Hits@1:0.232, Hits@10:0.503, MR:187.829, MRR:0.321, mean_loss:5.417
# Test-F-RH      :epoch:20, Hits@1:0.231, Hits@10:0.504, MR:162.491, MRR:0.321, mean_loss:5.417
# 2048 265 0.001 5.41692857742
# 2048 265 0.001 5.39638530983
# 2048 265 0.001 5.37790183481
# 2048 265 0.001 5.35956075236
# 2048 265 0.001 5.34269699241
# Valid-R        :epoch:25, Hits@1:0.112, Hits@10:0.324, MR:377.817, MRR:0.180, mean_loss:5.328
# Valid-R-RH     :epoch:25, Hits@1:0.112, Hits@10:0.326, MR:352.420, MRR:0.181, mean_loss:5.328
# Valid-F        :epoch:25, Hits@1:0.239, Hits@10:0.507, MR:182.489, MRR:0.327, mean_loss:5.328
# Valid-F-RH     :epoch:25, Hits@1:0.240, Hits@10:0.509, MR:156.830, MRR:0.328, mean_loss:5.328
# Test-R         :epoch:25, Hits@1:0.110, Hits@10:0.320, MR:381.860, MRR:0.178, mean_loss:5.328
# Test-R-RH      :epoch:25, Hits@1:0.111, Hits@10:0.322, MR:354.163, MRR:0.179, mean_loss:5.328
# Test-F         :epoch:25, Hits@1:0.236, Hits@10:0.502, MR:189.979, MRR:0.324, mean_loss:5.328
# Test-F-RH      :epoch:25, Hits@1:0.237, Hits@10:0.502, MR:161.820, MRR:0.325, mean_loss:5.328
# 2048 265 0.001 5.32822849166
# 2048 265 0.001 5.31192772343
# 2048 265 0.001 5.29807986134
# 2048 265 0.001 5.28348229966
# 2048 265 0.001 5.26974581053
# Valid-R        :epoch:30, Hits@1:0.108, Hits@10:0.320, MR:381.316, MRR:0.176, mean_loss:5.259
# Valid-R-RH     :epoch:30, Hits@1:0.109, Hits@10:0.322, MR:355.629, MRR:0.177, mean_loss:5.259
# Valid-F        :epoch:30, Hits@1:0.240, Hits@10:0.507, MR:182.400, MRR:0.329, mean_loss:5.259
# Valid-F-RH     :epoch:30, Hits@1:0.240, Hits@10:0.511, MR:156.745, MRR:0.329, mean_loss:5.259
# Test-R         :epoch:30, Hits@1:0.108, Hits@10:0.317, MR:387.217, MRR:0.175, mean_loss:5.259
# Test-R-RH      :epoch:30, Hits@1:0.108, Hits@10:0.320, MR:357.964, MRR:0.176, mean_loss:5.259
# Test-F         :epoch:30, Hits@1:0.237, Hits@10:0.502, MR:192.081, MRR:0.326, mean_loss:5.259
# Test-F-RH      :epoch:30, Hits@1:0.237, Hits@10:0.505, MR:162.473, MRR:0.326, mean_loss:5.259
# 2048 265 0.001 5.25856833548
# 2048 265 0.001 5.24609752691
# 2048 265 0.001 5.23457669852
# 2048 265 0.001 5.22275676727
# 2048 265 0.001 5.212598977
# Valid-R        :epoch:35, Hits@1:0.107, Hits@10:0.321, MR:382.231, MRR:0.175, mean_loss:5.204
# Valid-R-RH     :epoch:35, Hits@1:0.108, Hits@10:0.323, MR:356.548, MRR:0.176, mean_loss:5.204
# Valid-F        :epoch:35, Hits@1:0.239, Hits@10:0.510, MR:181.198, MRR:0.329, mean_loss:5.204
# Valid-F-RH     :epoch:35, Hits@1:0.238, Hits@10:0.513, MR:155.506, MRR:0.329, mean_loss:5.204
# Test-R         :epoch:35, Hits@1:0.107, Hits@10:0.317, MR:387.986, MRR:0.174, mean_loss:5.204
# Test-R-RH      :epoch:35, Hits@1:0.107, Hits@10:0.319, MR:359.634, MRR:0.175, mean_loss:5.204
# Test-F         :epoch:35, Hits@1:0.235, Hits@10:0.507, MR:190.438, MRR:0.326, mean_loss:5.204
# Test-F-RH      :epoch:35, Hits@1:0.236, Hits@10:0.510, MR:161.910, MRR:0.327, mean_loss:5.204
# 2048 265 0.001 5.20418232432
# 2048 265 0.001 5.19392409595
# 2048 265 0.001 5.18708831499
# 2048 265 0.001 5.17573521272
# 2048 265 0.001 5.16707684859
# Valid-R        :epoch:40, Hits@1:0.105, Hits@10:0.317, MR:384.963, MRR:0.173, mean_loss:5.162
# Valid-R-RH     :epoch:40, Hits@1:0.106, Hits@10:0.319, MR:358.368, MRR:0.174, mean_loss:5.162
# Valid-F        :epoch:40, Hits@1:0.243, Hits@10:0.508, MR:182.367, MRR:0.332, mean_loss:5.162
# Valid-F-RH     :epoch:40, Hits@1:0.245, Hits@10:0.511, MR:155.703, MRR:0.333, mean_loss:5.162
# Test-R         :epoch:40, Hits@1:0.102, Hits@10:0.316, MR:391.914, MRR:0.170, mean_loss:5.162
# Test-R-RH      :epoch:40, Hits@1:0.103, Hits@10:0.319, MR:361.848, MRR:0.171, mean_loss:5.162
# Test-F         :epoch:40, Hits@1:0.238, Hits@10:0.509, MR:193.077, MRR:0.328, mean_loss:5.162
# Test-F-RH      :epoch:40, Hits@1:0.240, Hits@10:0.510, MR:162.757, MRR:0.330, mean_loss:5.162
# 2048 265 0.001 5.16230807754
# 2048 265 0.001 5.1515387823
# 2048 265 0.001 5.14373488336
# 2048 265 0.001 5.13842415
# 2048 265 0.001 5.13106888465
# Valid-R        :epoch:45, Hits@1:0.104, Hits@10:0.318, MR:387.431, MRR:0.172, mean_loss:5.124
# Valid-R-RH     :epoch:45, Hits@1:0.105, Hits@10:0.321, MR:360.122, MRR:0.173, mean_loss:5.124
# Valid-F        :epoch:45, Hits@1:0.240, Hits@10:0.513, MR:183.384, MRR:0.330, mean_loss:5.124
# Valid-F-RH     :epoch:45, Hits@1:0.240, Hits@10:0.514, MR:156.023, MRR:0.331, mean_loss:5.124
# Test-R         :epoch:45, Hits@1:0.103, Hits@10:0.315, MR:395.034, MRR:0.170, mean_loss:5.124
# Test-R-RH      :epoch:45, Hits@1:0.104, Hits@10:0.317, MR:364.031, MRR:0.172, mean_loss:5.124
# Test-F         :epoch:45, Hits@1:0.238, Hits@10:0.507, MR:194.542, MRR:0.328, mean_loss:5.124
# Test-F-RH      :epoch:45, Hits@1:0.239, Hits@10:0.510, MR:163.327, MRR:0.329, mean_loss:5.124
# 2048 265 0.001 5.12433828138
# 2048 265 0.001 5.1166847103
# 2048 265 0.001 5.11085803194
# 2048 265 0.001 5.10418070127
# 2048 265 0.001 5.09799330729
# Valid-R        :epoch:50, Hits@1:0.102, Hits@10:0.316, MR:388.817, MRR:0.170, mean_loss:5.090
# Valid-R-RH     :epoch:50, Hits@1:0.103, Hits@10:0.318, MR:361.878, MRR:0.171, mean_loss:5.090
# Valid-F        :epoch:50, Hits@1:0.241, Hits@10:0.512, MR:183.096, MRR:0.331, mean_loss:5.090
# Valid-F-RH     :epoch:50, Hits@1:0.243, Hits@10:0.515, MR:156.253, MRR:0.334, mean_loss:5.090
# Test-R         :epoch:50, Hits@1:0.101, Hits@10:0.314, MR:394.594, MRR:0.169, mean_loss:5.090
# Test-R-RH      :epoch:50, Hits@1:0.102, Hits@10:0.317, MR:364.760, MRR:0.170, mean_loss:5.090
# Test-F         :epoch:50, Hits@1:0.236, Hits@10:0.508, MR:192.547, MRR:0.327, mean_loss:5.090
# Test-F-RH      :epoch:50, Hits@1:0.238, Hits@10:0.512, MR:162.567, MRR:0.329, mean_loss:5.090
# 2048 265 0.001 5.08953326963
# 2048 265 0.001 5.08534041711
# 2048 265 0.001 5.07751052964
# 2048 265 0.001 5.07410387903
# 2048 265 0.001 5.06673600719
# Valid-R        :epoch:55, Hits@1:0.102, Hits@10:0.316, MR:391.029, MRR:0.169, mean_loss:5.064
# Valid-R-RH     :epoch:55, Hits@1:0.103, Hits@10:0.318, MR:362.995, MRR:0.171, mean_loss:5.064
# Valid-F        :epoch:55, Hits@1:0.240, Hits@10:0.512, MR:184.279, MRR:0.330, mean_loss:5.064
# Valid-F-RH     :epoch:55, Hits@1:0.242, Hits@10:0.515, MR:156.396, MRR:0.333, mean_loss:5.064
# Test-R         :epoch:55, Hits@1:0.100, Hits@10:0.312, MR:398.463, MRR:0.167, mean_loss:5.064
# Test-R-RH      :epoch:55, Hits@1:0.100, Hits@10:0.315, MR:367.285, MRR:0.168, mean_loss:5.064
# Test-F         :epoch:55, Hits@1:0.237, Hits@10:0.508, MR:195.059, MRR:0.327, mean_loss:5.064
# Test-F-RH      :epoch:55, Hits@1:0.238, Hits@10:0.511, MR:163.915, MRR:0.329, mean_loss:5.064
# 2048 265 0.001 5.06393304501
# 2048 265 0.001 5.05744248516
# 2048 265 0.001 5.05180215296
# 2048 265 0.001 5.04957499234
# 2048 265 0.001 5.04279037692
# Valid-R        :epoch:60, Hits@1:0.100, Hits@10:0.315, MR:392.921, MRR:0.168, mean_loss:5.040
# Valid-R-RH     :epoch:60, Hits@1:0.101, Hits@10:0.318, MR:364.597, MRR:0.170, mean_loss:5.040
# Valid-F        :epoch:60, Hits@1:0.245, Hits@10:0.514, MR:185.506, MRR:0.334, mean_loss:5.040
# Valid-F-RH     :epoch:60, Hits@1:0.245, Hits@10:0.517, MR:157.162, MRR:0.335, mean_loss:5.040
# Test-R         :epoch:60, Hits@1:0.099, Hits@10:0.312, MR:400.349, MRR:0.166, mean_loss:5.040
# Test-R-RH      :epoch:60, Hits@1:0.099, Hits@10:0.316, MR:368.054, MRR:0.167, mean_loss:5.040
# Test-F         :epoch:60, Hits@1:0.237, Hits@10:0.511, MR:196.076, MRR:0.328, mean_loss:5.040
# Test-F-RH      :epoch:60, Hits@1:0.239, Hits@10:0.514, MR:163.748, MRR:0.330, mean_loss:5.040
# 2048 265 0.001 5.04012446493
# 2048 265 0.001 5.03296807127
# 2048 265 0.001 5.03126476576
# 2048 265 0.001 5.02343319407
# 2048 265 0.001 5.01988216796
# Valid-R        :epoch:65, Hits@1:0.100, Hits@10:0.314, MR:393.455, MRR:0.168, mean_loss:5.018
# Valid-R-RH     :epoch:65, Hits@1:0.101, Hits@10:0.318, MR:365.810, MRR:0.169, mean_loss:5.018
# Valid-F        :epoch:65, Hits@1:0.242, Hits@10:0.514, MR:185.875, MRR:0.332, mean_loss:5.018
# Valid-F-RH     :epoch:65, Hits@1:0.243, Hits@10:0.517, MR:158.061, MRR:0.334, mean_loss:5.018
# Test-R         :epoch:65, Hits@1:0.100, Hits@10:0.312, MR:400.302, MRR:0.167, mean_loss:5.018
# Test-R-RH      :epoch:65, Hits@1:0.100, Hits@10:0.315, MR:369.068, MRR:0.168, mean_loss:5.018
# Test-F         :epoch:65, Hits@1:0.239, Hits@10:0.510, MR:195.600, MRR:0.329, mean_loss:5.018
# Test-F-RH      :epoch:65, Hits@1:0.240, Hits@10:0.514, MR:164.275, MRR:0.331, mean_loss:5.018
# 2048 265 0.001 5.01785288037
# 2048 265 0.001 5.01287168107
# 2048 265 0.001 5.00889180921
# 2048 265 0.001 5.00564797239
# 2048 265 0.001 5.00099522933
# Valid-R        :epoch:70, Hits@1:0.100, Hits@10:0.315, MR:391.632, MRR:0.167, mean_loss:4.998
# Valid-R-RH     :epoch:70, Hits@1:0.101, Hits@10:0.318, MR:364.829, MRR:0.169, mean_loss:4.998
# Valid-F        :epoch:70, Hits@1:0.244, Hits@10:0.517, MR:183.271, MRR:0.333, mean_loss:4.998
# Valid-F-RH     :epoch:70, Hits@1:0.245, Hits@10:0.518, MR:156.502, MRR:0.336, mean_loss:4.998
# Test-R         :epoch:70, Hits@1:0.098, Hits@10:0.313, MR:399.927, MRR:0.165, mean_loss:4.998
# Test-R-RH      :epoch:70, Hits@1:0.099, Hits@10:0.316, MR:369.292, MRR:0.167, mean_loss:4.998
# Test-F         :epoch:70, Hits@1:0.240, Hits@10:0.511, MR:194.308, MRR:0.330, mean_loss:4.998
# Test-F-RH      :epoch:70, Hits@1:0.243, Hits@10:0.514, MR:163.690, MRR:0.333, mean_loss:4.998
# 2048 265 0.001 4.99784427319
# 2048 265 0.001 4.99378493687
# 2048 265 0.001 4.99174360959
# 2048 265 0.001 4.98927046038
# 2048 265 0.001 4.98033351898
# Valid-R        :epoch:75, Hits@1:0.099, Hits@10:0.313, MR:394.194, MRR:0.166, mean_loss:4.979
# Valid-R-RH     :epoch:75, Hits@1:0.100, Hits@10:0.317, MR:366.314, MRR:0.167, mean_loss:4.979
# Valid-F        :epoch:75, Hits@1:0.247, Hits@10:0.517, MR:185.268, MRR:0.336, mean_loss:4.979
# Valid-F-RH     :epoch:75, Hits@1:0.248, Hits@10:0.521, MR:157.421, MRR:0.338, mean_loss:4.979
# Test-R         :epoch:75, Hits@1:0.098, Hits@10:0.313, MR:402.491, MRR:0.165, mean_loss:4.979
# Test-R-RH      :epoch:75, Hits@1:0.098, Hits@10:0.315, MR:371.056, MRR:0.166, mean_loss:4.979
# Test-F         :epoch:75, Hits@1:0.241, Hits@10:0.511, MR:196.598, MRR:0.331, mean_loss:4.979
# Test-F-RH      :epoch:75, Hits@1:0.242, Hits@10:0.515, MR:165.154, MRR:0.333, mean_loss:4.979
# 2048 265 0.001 4.97874153425
# 2048 265 0.001 4.976642148
# 2048 265 0.001 4.97247123718
# 2048 265 0.001 4.9684076903
# 2048 265 0.001 4.96672369939
# Valid-R        :epoch:80, Hits@1:0.100, Hits@10:0.312, MR:392.618, MRR:0.167, mean_loss:4.964
# Valid-R-RH     :epoch:80, Hits@1:0.101, Hits@10:0.314, MR:365.619, MRR:0.168, mean_loss:4.964
# Valid-F        :epoch:80, Hits@1:0.245, Hits@10:0.516, MR:183.435, MRR:0.335, mean_loss:4.964
# Valid-F-RH     :epoch:80, Hits@1:0.247, Hits@10:0.520, MR:156.376, MRR:0.337, mean_loss:4.964
# Test-R         :epoch:80, Hits@1:0.097, Hits@10:0.310, MR:401.573, MRR:0.164, mean_loss:4.964
# Test-R-RH      :epoch:80, Hits@1:0.098, Hits@10:0.313, MR:371.033, MRR:0.165, mean_loss:4.964
# Test-F         :epoch:80, Hits@1:0.238, Hits@10:0.512, MR:195.086, MRR:0.329, mean_loss:4.964
# Test-F-RH      :epoch:80, Hits@1:0.240, Hits@10:0.516, MR:164.532, MRR:0.331, mean_loss:4.964
# 2048 265 0.001 4.96424546332
# 2048 265 0.001 4.95985659473
# 2048 265 0.001 4.95695340139
# 2048 265 0.001 4.95389783068
# 2048 265 0.001 4.94921329246
# Valid-R        :epoch:85, Hits@1:0.098, Hits@10:0.312, MR:395.383, MRR:0.165, mean_loss:4.952
# Valid-R-RH     :epoch:85, Hits@1:0.098, Hits@10:0.315, MR:367.515, MRR:0.166, mean_loss:4.952
# Valid-F        :epoch:85, Hits@1:0.243, Hits@10:0.516, MR:185.401, MRR:0.334, mean_loss:4.952
# Valid-F-RH     :epoch:85, Hits@1:0.244, Hits@10:0.520, MR:157.512, MRR:0.336, mean_loss:4.952
# Test-R         :epoch:85, Hits@1:0.096, Hits@10:0.310, MR:401.881, MRR:0.163, mean_loss:4.952
# Test-R-RH      :epoch:85, Hits@1:0.097, Hits@10:0.313, MR:371.249, MRR:0.164, mean_loss:4.952
# Test-F         :epoch:85, Hits@1:0.238, Hits@10:0.515, MR:194.810, MRR:0.329, mean_loss:4.952
# Test-F-RH      :epoch:85, Hits@1:0.239, Hits@10:0.517, MR:164.104, MRR:0.332, mean_loss:4.952
# 2048 265 0.001 4.95161574742
# 2048 265 0.001 4.94409687474
# 2048 265 0.001 4.9428987773
# 2048 265 0.001 4.93988783135
# 2048 265 0.001 4.93575757405
# Valid-R        :epoch:90, Hits@1:0.098, Hits@10:0.312, MR:396.602, MRR:0.165, mean_loss:4.932
# Valid-R-RH     :epoch:90, Hits@1:0.098, Hits@10:0.315, MR:367.650, MRR:0.166, mean_loss:4.932
# Valid-F        :epoch:90, Hits@1:0.247, Hits@10:0.519, MR:186.500, MRR:0.337, mean_loss:4.932
# Valid-F-RH     :epoch:90, Hits@1:0.249, Hits@10:0.522, MR:157.575, MRR:0.339, mean_loss:4.932
# Test-R         :epoch:90, Hits@1:0.097, Hits@10:0.308, MR:403.780, MRR:0.163, mean_loss:4.932
# Test-R-RH      :epoch:90, Hits@1:0.097, Hits@10:0.312, MR:371.866, MRR:0.164, mean_loss:4.932
# Test-F         :epoch:90, Hits@1:0.240, Hits@10:0.513, MR:196.333, MRR:0.331, mean_loss:4.932
# Test-F-RH      :epoch:90, Hits@1:0.243, Hits@10:0.517, MR:164.402, MRR:0.334, mean_loss:4.932
# 2048 265 0.001 4.93240266836
# 2048 265 0.001 4.93030029153
# 189 4.96429
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3728728562bd> in <module>()
#       2     if i % 5 == 0:
#       3         handle_eval(i=i, last_mean_loss=last_mean_loss, valid=True, test=True)
# ----> 4     last_mean_loss = model.train()
#       5     epoch += 1
#
# ~/Projects/kgcompletion/implementations/DSKG/model.py in train(self, t_labels, r_labels)
#     314             feed_dict[self._r] = one_batch_data[:, 1]
#     315             feed_dict[self._label] = one_batch_data[:, 2]
# --> 316             vals = self._session.run(fetches, feed_dict)
#     317
#     318             del one_batch_data
#
# ~/.pyenv/versions/py3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.pyenv/versions/py3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/.pyenv/versions/py3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/.pyenv/versions/py3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~/.pyenv/versions/py3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
